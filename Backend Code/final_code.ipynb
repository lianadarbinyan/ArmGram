# %%
from all_in_one import all_in_one

# %%
text = 'մեղրի որ հիմնական սա բաղադրիչը յուրացվող ածխաջրերն սա են՝ որ խաղոաշաքարն, սա ու պտղաշաքարը, սա որոնց պարունակությունը որ հասում է, ինչի շնորհիվ որ մեղրը հեշտ է որ մարսվում։ մեղրի որ կարևոր բաղադրամասերից են որ օրգանական'

# %%
alls = all_in_one(text)

# %%
alls.all_methods()
# Out:
# ['Միգուցե նկատի ունեք՝', 'խաղոաշաքարն -  խաղողաշաքարն', "Ցավոք 'խաղոաշաքարն' բառը բառարանում առկա չէ։"]
# ["«որ» բառի կրկնությունից խուսափելու համար՝ բառը փոխարինեք ['թե', 'եթե', 'որպեսզի', 'որովհետև', 'թեև', 'թեկուզ', 'թեպետ', 'որոնք', 'մինչ', 'մինչև', 'քան', 'բայց', 'ու', 'թե', 'սակայն', 'իսկ', 'քանի որ'] բառերից մեկով:"]
# []
# ...

# %%
alls.text
# Out:
# 'Մեղրի, որ հիմնական սա բաղադրիչը յուրացվող ածխաջրերն սա են՝, որ խաղոաշաքարն, սա, ու պտղաշաքարը, սա, որոնց պարունակությունը, որ հասում է, ինչի շնորհիվ, որ մեղրը հեշտ է, որ մարսվում։ Մեղրի, որ կարևոր բաղադրամասերից են, որ օրգանական։ '

# %%
alls.wrongs
# Out:
# ['խաղոաշաքարն,', 'մեղրի,']
